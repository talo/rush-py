# %% [markdown]
# ## Constrained docking protocol
#
# In this tutorial, we will demonstrate how you can use `rush-py` to conduct a large-scale virtual screen on a target using a constrained docking protocol.
#
# We will use the Zinc20 database of FDA approved drugs as our sample ligand database, but Rush's capability means that this protocol could scale to screen tens of millions of ligands.

# %% [markdown]
# ## 0.0) Imports

# %%
import requests
import csv
import shutil
import json
import numpy as np
from pathlib import Path
from enum import Enum

from rdkit.Chem import MolFromSmiles, MolToSmiles
from rdkit.Chem import AllChem, SDMolSupplier
from rdkit.Chem import rdFMCS, rdRascalMCES
from rdkit.Chem import rdDistGeom
from rdkit import Chem
from rdkit.Chem.rdMolAlign import AlignMol
from rdkit.Chem import rdForceFieldHelpers

from typing import List, Optional

# %% [markdown]
# ## 1.1) Configuration

# %%
# |hide
import os
import pathlib

WORK_DIR = pathlib.Path("~/qdx/constrained-docking/").expanduser()
if WORK_DIR.exists():
    # !rm -r $WORK_DIR
os.makedirs(WORK_DIR)
os.chdir(WORK_DIR)

# %%
# Define our project information
DESCRIPTION = "rush-py constrained docking protocol"
TAGS = ["qdx", "rush-py-v2", "demo", "contrained-docking"]
WORK_DIR = Path.home() / "qdx" / "constrained-docking"

# %%
import rush
import asyncio

client = await rush.build_provider_with_functions()

# %% [markdown]
# ## 0.1) Virtual screen configuration
# The expectation for using this virtual screen is that you will have a protein with a characterized binding ligand and you will want to try to dock a set of alternate targets to the protein.
# You should save files to the same directory that you run this notebook in.
#
# The key configuration items are:
#
# `REFERENCE_LIGAND_FILEPATH`: the path to a SDF file containing a known binder for your protein target.
#
# `PROTEIN_TARGET_FILEPATH`: the path to a PDB file containing your protein target. Please note that the binder must be removed.
#
# `VIRTUAL_SCREEN_LIBRARY_URL`: a URL to a Zinc20 csv virtual screen database download.
#
# `SORT_BY`: sort the GNINA minimised poses output by a particular score. For more information on GNINA outputs, see [here](https://github.com/gnina/gnina).

# %% [markdown]
# ## 0.2)
# For this example, we will fetch an example protein and ligand from RCSB. We are using CDK with the JWS648 inhibitor as a known ligand to serve as our template.

# %%
class SortKey(Enum):
    CNN_SCORE = "cnn_score"
    AFFINITY = "affinity"
    CNN_AFFINITY = "cnn_affinity"


REFERENCE_LIGAND_FILEPATH = Path.cwd() / "3pxy_B_JWS.sdf"
PROTEIN_TARGET_FILEPATH = Path.cwd() / "3pxy_cleaned.pdb"
VIRTUAL_SCREEN_LIBRARY_URL = (
    "https://zinc20.docking.org/substances/subsets/fda.csv?count=all"
)
SORT_BY = SortKey.CNN_SCORE

OBJECT_POSE_FILEPATH = Path.cwd() / "objects"

# %%
# !pdb_fetch '3pxy' |  pdb_delhetatm > 3pxy_cleaned.pdb
REFERENCE_LIGAND_FILEPATH.write_bytes(
    requests.get(
        "https://models.rcsb.org/v1/3pxy/ligand?auth_seq_id=299&label_asym_id=B&encoding=sdf&filename=3pxy_B_JWS.sdf"
    ).content
)
# !ls
# Out:
# 3pxy_B_JWS.sdf	3pxy_cleaned.pdb

# %% [markdown]
# ## 0.1) Constrained docking code
# The below block of code is the set of helpers functions necessary for performing constrained docking as part of a large-scale virtual screen.

# %%
MCS_FAILURES = []
ALIGNMENT_FAILURES = []


def get_mcs(
    query_ligand: Chem.Mol, reference: Chem.Mol, timeout=20, **kwargs
) -> Optional[Chem.Mol]:
    if kwargs.get("ignore_heavy_atom"):
        atom_comparision_method = rdFMCS.AtomCompare.CompareAnyHeavyAtom
    else:
        atom_comparision_method = rdFMCS.AtomCompare.CompareElements

    if kwargs.get("ignore_bond_order"):
        bond_comparision_method = rdFMCS.BondCompare.CompareAny
    else:
        bond_comparision_method = rdFMCS.BondCompare.CompareOrder

    if kwargs.get("use_rascal_mces"):
        mcs = rdRascalMCES.FindMCES(
            [reference, query_ligand],
            atomCompare=atom_comparision_method,
            bondCompare=bond_comparision_method,
        )

    else:
        mcs = rdFMCS.FindMCS(
            [reference, query_ligand],
            threshold=0.9,
            completeRingsOnly=kwargs.get("complete_rings_only", True),
            atomCompare=atom_comparision_method,
            bondCompare=bond_comparision_method,
            timeout=timeout,
        )
    if meets_similarity_threshold(mcs, query_ligand, reference):
        return Chem.MolFromSmarts(mcs.smartsString, mergeHs=True)
    return None


def meets_similarity_threshold(
    mcs, query_ligand: Chem.Mol, reference: Chem.Mol, min_threshold=0.20
) -> bool:
    if mcs_result_exists(mcs, query_ligand):
        mcs_mol = Chem.MolFromSmarts(mcs.smartsString, mergeHs=True)
        match_ratio = min(
            mcs_mol.GetNumAtoms() / query_ligand.GetNumAtoms(),
            mcs_mol.GetNumAtoms() / reference.GetNumAtoms(),
        )
        return match_ratio >= min_threshold

    return False


INITIAL_FILTER_DISTANCE = 1000


def get_diverse_substructure_matches(
    reference, mcs_mol, minimum_difference=5
) -> List[Chem.Mol]:
    """
    Prunes a list of MCS substructure hits within a molecule and keeps only those which are at least the minimum difference apart
    This is to capture as many unique substructure hits across the query and the ligand, but discard those that are not meaningfully different (e.g. a rotation of the bond)
    A default of 5 is an effective balance between retaining novel hits and discarding excessively similar values.
    """
    substructures = reference.GetSubstructMatches(mcs_mol, uniquify=False)

    output_structures = [substructures[0]]
    for substructure in substructures[1:]:
        distance = INITIAL_FILTER_DISTANCE
        j = 0

        while (distance >= minimum_difference) and j < len(output_structures):
            ref = np.array(output_structures[j])
            distance = sum(np.array(substructure) != ref)
            j += 1

        if distance >= minimum_difference:
            output_structures.append(substructure)

    return output_structures


def get_tethered_atoms(substruct_match) -> str:
    """
    Return a formatted string of atom indexes to pass to "TETHERED ATOMS" configuration option for rxdock

    Example input:
    (0, 1, 2)

    Example output:
    1,2,3
    """
    return ",".join(str(index + 1) for index in substruct_match)


def mcs_result_exists(mcs, query) -> bool:
    return mcs.smartsString and len(mcs.smartsString) > 0


def get_force_field(geom_calc, query_mol):
    ff = rdForceFieldHelpers.UFFGetMoleculeForceField(query_mol, confId=0)

    for i in geom_calc.coordMap:
        point = geom_calc.coordMap[i]
        point_idx = ff.AddExtraPoint(point.x, point.y, point.z, fixed=True) - 1
        ff.AddDistanceConstraint(point_idx, i, 0, 0, 100.0)
    ff.Initialize()

    return ff


def get_template_aligned_pose(
    query, reference, query_ligand_map, geom_calc, n_tries=5
) -> Chem.Mol:
    """
    Align query molecule to "template" (reference molecule)
    Distance constrints are enforced on the input ligand to mould the geometry of its matching substructure to that in the template
    """
    temp_query_mol = Chem.Mol(query)

    min_energy = np.inf
    bestmol = None

    for _ in range(n_tries):
        # Repeat the alignment step at each starting configuration
        # Places internal geometry (bond angles, torsion, etc) of parts of the ligand
        # that matches that in the reference
        # Need to error here if ci > 0
        AllChem.EmbedMolecule(temp_query_mol, geom_calc)

        # This step is critical as it places the molecule in a good starting position relative to the reference
        try:
            AlignMol(temp_query_mol, reference, atomMap=query_ligand_map)
        except:
            print(f"Failed to align {MolToSmiles(query)}")
            ALIGNMENT_FAILURES.append(temp_query_mol)

        try:
            ff = get_force_field(geom_calc, temp_query_mol)
        except:
            print(f"Failed to get forcefield for {MolToSmiles(temp_query_mol)}")
            return bestmol

        minimize_tries = 4
        more_to_minimize = ff.Minimize(energyTol=1e-4, forceTol=1e-3)
        while more_to_minimize and minimize_tries:
            more_to_minimize = ff.Minimize(energyTol=1e-4, forceTol=1e-3)
            minimize_tries -= 1
        current_energy = ff.CalcEnergy()

        if current_energy < min_energy:
            bestmol = Chem.Mol(temp_query_mol)
            min_energy = current_energy
        temp_query_mol = Chem.Mol(query)

        try:
            AlignMol(temp_query_mol, reference, atomMap=query_ligand_map)
        except:
            print(f"Failed to align {MolToSmiles(query)}")
            ALIGNMENT_FAILURES.append(temp_query_mol)

    return bestmol


def get_substructure_matches(molecule, mcs_mol, uniquify=True) -> Chem.Mol:
    return molecule.GetSubstructMatches(mcs_mol, uniquify=uniquify)


def get_dist_geom_calculator(
    reference, query_matches, reference_match, constrained_atoms
):
    geom_calc = rdDistGeom.ETKDGv3()
    geom_calc.trackFailures = True
    geom_calc.coordMap = {
        query_matches[atom_idx]: reference.GetConformer().GetAtomPosition(
            reference_match[atom_idx]
        )
        for atom_idx in range(len(constrained_atoms))
    }

    return geom_calc


def get_initial_poses(query, reference, max_symmetry=5):
    """
    Use maximum common substructure between query and template ligand to generate initial docking poses
    of query ligand

    """
    mcs_mol = get_mcs(query, reference)
    if not mcs_mol:
        MCS_FAILURES.append(mcs_mol)
        return []
    reference_matches = get_diverse_substructure_matches(reference, mcs_mol)
    molecule_matches = get_substructure_matches(query, mcs_mol)

    constrained_atoms = molecule_matches[0]
    constrained_atom_ids = get_tethered_atoms(constrained_atoms)

    molhits = query.GetSubstructMatch(mcs_mol)

    poses = []

    n_iterations = min(len(reference_matches), max_symmetry)

    for i in range(n_iterations):
        geom_calc = get_dist_geom_calculator(
            reference, molhits, reference_matches[i], constrained_atoms
        )

        posed_mol = get_template_aligned_pose(
            query,
            reference,
            [
                (m_idx, r_idx)
                for m_idx, r_idx in zip(molhits, reference_matches[i])
            ],
            geom_calc,
        )
        if posed_mol:
            posed_mol.SetProp("TETHERED ATOMS", constrained_atom_ids)
            poses.append(posed_mol)

    return poses

# %% [markdown]
# ## 1.0) Virtual screen library
# This section contains the section for downloading a virtual screen library from Zinc20 and converting it into RDKit molecules we can constrain

# %%
def load_zinc20_virtual_screen_library(url) -> List[Chem.Mol]:
    ligands = []
    with requests.get(url, stream=True) as response:
        response.raise_for_status()

        lines = (line.decode("utf-8") for line in response.iter_lines())
        reader = csv.DictReader(lines)

        for row in reader:
            if "smiles" in row:
                mol = MolFromSmiles(row["smiles"])
                mol = Chem.AddHs(mol)
                # For reproducibility. In principle it won't matter much because we're moving it to fit the template
                Chem.rdDistGeom.EmbedMolecule(mol, 1, randomSeed=0xF00D)
                mol.SetProp("ZINC_ID", row["zinc_id"])

                ligands.append(mol)

    return ligands


query_ligands = load_zinc20_virtual_screen_library(VIRTUAL_SCREEN_LIBRARY_URL)
# Out:
# [01:18:01] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [01:18:01] UFFTYPER: Warning: hybridization set to SP3 for atom 8
# [01:18:03] UFFTYPER: Unrecognized atom type: S_6+6 (1)

# %%
suppl = SDMolSupplier(REFERENCE_LIGAND_FILEPATH)
reference_ligand = suppl[0]
assert reference_ligand is not None
# Out:
# [01:18:34] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.

# %% [markdown]
# ## 1.1) Generate initial poses
# In this stage, we generate initial constrained poses from our query ligands that we will feed to our docking pipeline.

# %%
from mpire import WorkerPool
import multiprocessing

poses = []


def process_query_ligand(query_ligand):
    """Function to process each query ligand with get_initial_poses"""
    # print(MolToSmiles(query_ligand))
    return get_initial_poses(query_ligand, reference_ligand)


num_processes = max(multiprocessing.cpu_count() - 5, 1)

with WorkerPool(n_jobs=num_processes, enable_insights=True) as pool:
    poses.extend(pool.map_unordered(process_query_ligand, query_ligands))
# Out:
# Failed to align [H]c1c(OC([H])([H])[C@@]2([H])OC(=O)N([H])C2([H])[H])c([H])c(C([H])([H])[H])c([H])c1C([H])([H])[H]
# Failed to align [H]c1c(OC([H])([H])[C@@]2([H])OC(=O)N([H])C2([H])[H])c([H])c(C([H])([H])[H])c([H])c1C([H])([H])[H]
# Failed to align [H]N([H])C12C([H])([H])C3([H])C([H])([H])[C@@](C([H])([H])[H])(C1([H])[H])C([H])([H])[C@](C([H])([H])[H])(C3([H])[H])C2([H])[H]Failed to align [H]c1c([H])c([H])c(C(=O)[C@]([H])(N(C([H])([H])C([H])([H])[H])C([H])([H])C([H])([H])[H])C([H])([H])[H])c([H])c1[H]
#
# Failed to align [H]c1c(OC([H])([H])[C@@]2([H])OC(=O)N([H])C2([H])[H])c([H])c(C([H])([H])[H])c([H])c1C([H])([H])[H]
# Failed to align [H]Oc1c([H])c([H])c(O[C@]2([H])O[C@]([H])(C([H])([H])O[H])[C@@]([H])(O[H])[C@]([H])(O[H])[C@@]2([H])O[H])c([H])c1[H]
# Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=O
# Failed to align [H]c1c(OC([H])([H])[C@@]2([H])OC(=O)N([H])C2([H])[H])c([H])c(C([H])([H])[H])c([H])c1C([H])([H])[H]
# Failed to align [H]N([H])C12C([H])([H])C3([H])C([H])([H])[C@@](C([H])([H])[H])(C1([H])[H])C([H])([H])[C@](C([H])([H])[H])(C3([H])[H])C2([H])[H]
# Failed to align [H]c1c([H])c([H])c(C(=O)[C@]([H])(N(C([H])([H])C([H])([H])[H])C([H])([H])C([H])([H])[H])C([H])([H])[H])c([H])c1[H]
# Failed to align [H]c1c([H])c([H])c(C2=NC([H])([H])c3nnc([H])n3-c3c([H])c([H])c(Cl)c([H])c32)c([H])c1[H]
# Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=O
# Failed to align [H]c1c(OC([H])([H])[C@@]2([H])OC(=O)N([H])C2([H])[H])c([H])c(C([H])([H])[H])c([H])c1C([H])([H])[H]
# Failed to align [H]Oc1c([H])c([H])c(O[C@]2([H])O[C@]([H])(C([H])([H])O[H])[C@@]([H])(O[H])[C@]([H])(O[H])[C@@]2([H])O[H])c([H])c1[H]Failed to align [H]N([H])C12C([H])([H])C3([H])C([H])([H])[C@@](C([H])([H])[H])(C1([H])[H])C([H])([H])[C@](C([H])([H])[H])(C3([H])[H])C2([H])[H]
#
# Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=O
# Failed to align [H]c1c([H])c([H])c(C2=NC([H])([H])c3nnc([H])n3-c3c([H])c([H])c(Cl)c([H])c32)c([H])c1[H]
# Failed to align [H]c1c([H])c([H])c(C(=O)[C@]([H])(N(C([H])([H])C([H])([H])[H])C([H])([H])C([H])([H])[H])C([H])([H])[H])c([H])c1[H]
# Failed to align [H]N([H])C12C([H])([H])C3([H])C([H])([H])[C@@](C([H])([H])[H])(C1([H])[H])C([H])([H])[C@](C([H])([H])[H])(C3([H])[H])C2([H])[H]
# Failed to align [H]c1nc([H])c(Cl)c(N([H])C(=O)c2c([H])c([H])c(OC([H])(F)F)c(OC([H])([H])C3([H])C([H])([H])C3([H])[H])c2[H])c1Cl
# Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=O
# Failed to align [H]c1c([H])c([H])c(C2=NC([H])([H])c3nnc([H])n3-c3c([H])c([H])c(Cl)c([H])c32)c([H])c1[H]
# Failed to align [H]Oc1c([H])c([H])c(O[C@]2([H])O[C@]([H])(C([H])([H])O[H])[C@@]([H])(O[H])[C@]([H])(O[H])[C@@]2([H])O[H])c([H])c1[H]
# Failed to align [H]N([H])C12C([H])([H])C3([H])C([H])([H])[C@@](C([H])([H])[H])(C1([H])[H])C([H])([H])[C@](C([H])([H])[H])(C3([H])[H])C2([H])[H]
# Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=O
# Failed to align [H]c1c([H])c([H])c(C(=O)[C@]([H])(N(C([H])([H])C([H])([H])[H])C([H])([H])C([H])([H])[H])C([H])([H])[H])c([H])c1[H]
# Failed to align [H]c1c([H])c([H])c(C2=NC([H])([H])c3nnc([H])n3-c3c([H])c([H])c(Cl)c([H])c32)c([H])c1[H]
# Failed to align [H]c1c([H])c(Cl)c([H])c(C(=O)[C@@]([H])(N([H])C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])c1[H]Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=O
#
# Failed to align [H]Oc1c([H])c([H])c(O[C@]2([H])O[C@]([H])(C([H])([H])O[H])[C@@]([H])(O[H])[C@]([H])(O[H])[C@@]2([H])O[H])c([H])c1[H]
# Failed to align [H]c1c([H])c([H])c(C(=O)[C@]([H])(N(C([H])([H])C([H])([H])[H])C([H])([H])C([H])([H])[H])C([H])([H])[H])c([H])c1[H]
# Failed to align [H]c1c([H])c([H])c(C2=NC([H])([H])c3nnc([H])n3-c3c([H])c([H])c(Cl)c([H])c32)c([H])c1[H]
# Failed to align [H]c1nc([H])c(Cl)c(N([H])C(=O)c2c([H])c([H])c(OC([H])(F)F)c(OC([H])([H])C3([H])C([H])([H])C3([H])[H])c2[H])c1Cl
# Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=O
# Failed to align [H]OC(=O)c1sc(-c2c([H])c([H])c(OC([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H])c(C#N)c2[H])nc1C([H])([H])[H]
# Failed to align [H]c1c([H])c(S(=O)(=O)N([H])[H])c([H])c([H])c1C([H])([H])N([H])[H]
# Failed to align [H]Oc1c([H])c([H])c(O[C@]2([H])O[C@]([H])(C([H])([H])O[H])[C@@]([H])(O[H])[C@]([H])(O[H])[C@@]2([H])O[H])c([H])c1[H]
# Failed to align [H]c1c([H])c(Cl)c([H])c(C(=O)[C@@]([H])(N([H])C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])c1[H]
# Failed to align [H]c1c([H])c(S(=O)(=O)N([H])[H])c([H])c([H])c1C([H])([H])N([H])[H]
# Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=O
# Failed to align [H]c1c([H])c(S(=O)(=O)N([H])[H])c([H])c([H])c1C([H])([H])N([H])[H]
# Failed to align [H]OC([H])([H])[C@@]1([H])O[C@@]([H])(n2c([H])nc(N([H])[H])nc2=O)[C@]([H])(O[H])[C@]1([H])O[H]
# Failed to align [H]c1c([H])c(S(=O)(=O)N([H])[H])c([H])c([H])c1C([H])([H])N([H])[H]
# Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=O
# Failed to align [H]c1c([H])c(Cl)c([H])c(C(=O)[C@@]([H])(N([H])C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])c1[H]
# Failed to align [H]c1c([H])c(S(=O)(=O)N([H])[H])c([H])c([H])c1C([H])([H])N([H])[H]
# Failed to align [H]OC(=O)c1sc(-c2c([H])c([H])c(OC([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H])c(C#N)c2[H])nc1C([H])([H])[H]
# Failed to align [H]OC([H])([H])[C@@]1([H])O[C@@]([H])(n2c([H])nc(N([H])[H])nc2=O)[C@]([H])(O[H])[C@]1([H])O[H]Failed to align [H]c1nc([H])c(Cl)c(N([H])C(=O)c2c([H])c([H])c(OC([H])(F)F)c(OC([H])([H])C3([H])C([H])([H])C3([H])[H])c2[H])c1Cl
#
# Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=O
# Failed to align [H]OS(=O)(=O)c1c([H])c([H])c2c(nc(-c3c([H])c([H])c([H])c([H])c3[H])n2[H])c1[H]
# Failed to align [H]c1c([H])c(Cl)c([H])c(C(=O)[C@@]([H])(N([H])C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])c1[H]
# Failed to align [H]OC([H])([H])[C@@]1([H])O[C@@]([H])(n2c([H])nc(N([H])[H])nc2=O)[C@]([H])(O[H])[C@]1([H])O[H]
# Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=O
# Failed to align [H]OS(=O)(=O)c1c([H])c([H])c2c(nc(-c3c([H])c([H])c([H])c([H])c3[H])n2[H])c1[H]
# Failed to align [H]OC(=O)c1sc(-c2c([H])c([H])c(OC([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H])c(C#N)c2[H])nc1C([H])([H])[H]
# Failed to align [H]OC([H])([H])[C@@]1([H])O[C@@]([H])(n2c([H])nc(N([H])[H])nc2=O)[C@]([H])(O[H])[C@]1([H])O[H]
# Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=OFailed to align [H]OS(=O)(=O)c1c([H])c([H])c2c(nc(-c3c([H])c([H])c([H])c([H])c3[H])n2[H])c1[H]
#
# Failed to align [H]c1nc([H])c(Cl)c(N([H])C(=O)c2c([H])c([H])c(OC([H])(F)F)c(OC([H])([H])C3([H])C([H])([H])C3([H])[H])c2[H])c1Cl
# Failed to align [H]c1c([H])c(Cl)c([H])c(C(=O)[C@@]([H])(N([H])C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])C([H])([H])[H])c1[H]Failed to align [H]OC([H])([H])[C@@]1([H])O[C@@]([H])(n2c([H])nc(N([H])[H])nc2=O)[C@]([H])(O[H])[C@]1([H])O[H]
#
# Failed to align [H]OC(=O)c1sc(-c2c([H])c([H])c(OC([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H])c(C#N)c2[H])nc1C([H])([H])[H]Failed to align [H]OS(=O)(=O)c1c([H])c([H])c2c(nc(-c3c([H])c([H])c([H])c([H])c3[H])n2[H])c1[H]
# Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=O
# Failed to align [H]OC([H])([H])[C@@]1([H])O[C@@]([H])(n2c([H])nc(N([H])[H])nc2=O)[C@]([H])(O[H])[C@]1([H])O[H]
#
# Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=O
# Failed to align [H]OC(=O)C([H])([H])c1c([H])c([H])c([H])c([H])c1[H]
# Failed to align [H]c1nc([H])c(Cl)c(N([H])C(=O)c2c([H])c([H])c(OC([H])(F)F)c(OC([H])([H])C3([H])C([H])([H])C3([H])[H])c2[H])c1Cl
# Failed to align [H]OC(=O)C([H])([H])c1c([H])c([H])c([H])c([H])c1[H]
# Failed to align [H]OC(=O)c1sc(-c2c([H])c([H])c(OC([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H])c(C#N)c2[H])nc1C([H])([H])[H]
# Failed to align [H]c1c([H])c([H])c2c(c1[H])C(=O)N([C@@]1([H])C(=O)N([H])C(=O)C([H])([H])C1([H])[H])C2=OFailed to align [H]OS(=O)(=O)c1c([H])c([H])c2c(nc(-c3c([H])c([H])c([H])c([H])c3[H])n2[H])c1[H]
# Failed to align [H]OC(=O)C([H])([H])c1c([H])c([H])c([H])c([H])c1[H]
#
# Failed to align [H]c1c([H])c([H])c(C([H])(c2c([H])c([H])c([H])c([H])c2[H])[S@](=O)C([H])([H])C(=O)N([H])[H])c([H])c1[H]Failed to align [H]OC(=O)C([H])([H])c1c([H])c([H])c([H])c([H])c1[H]
],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcc630>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcc810>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcc7c0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcc860>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcc8b0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcc900>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcc950>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcc9a0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcc9f0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcca40>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcca90>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bccae0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bccb30>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bccb80>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bccc20>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bccd60>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bccbd0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcccc0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bccd10>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bccc70>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bccdb0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcce00>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bccef0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bccf40>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bccf90>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bccfe0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcd030>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcce50>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd0d0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bccea0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd080>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcd120>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcd210>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcd260>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcd2b0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd300>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd3a0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcd1c0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd170>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd3f0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9b9fdd0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd350>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcd4e0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcd530>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcd580>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcd5d0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd6c0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd620>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd670>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd710>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd760>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd7b0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd8a0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd800>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd940>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcd8f0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcd990>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcd850>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcd9e0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcda30>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcda80>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcdad0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcdb20>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcdbc0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcdc10>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcdc60>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcdb70>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcdcb0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcdd00>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcdd50>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcddf0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcde40>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcdee0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcdda0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcdf30>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcdf80>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcde90>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcdfd0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce0c0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce110>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bce020>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bce070>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bce1b0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bce160>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce200>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce2f0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce2a0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce340>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce250>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce430>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce4d0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce520>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bce390>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bce480>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bce3e0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bce570>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce610>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce5c0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce700>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bce660>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce750>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce7a0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce890>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce6b0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce840>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce7f0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce8e0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce980>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bceac0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bce930>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcea20>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bce9d0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcea70>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bceb10>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bceb60>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcec00>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcebb0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcec50>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcecf0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bceca0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bced90>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bced40>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcee30>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcef20>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcee80>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bceed0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcede0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcef70>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcefc0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcf010>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcf060>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf0b0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf100>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf150>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf1a0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcf240>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf290>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf2e0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf330>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf1f0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcf420>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcf380>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf3d0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf4c0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf510>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf560>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcf600>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf470>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf5b0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf6a0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf650>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcf6f0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf790>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf740>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf7e0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf830>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcf920>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcfa10>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcf9c0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcf970>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcfa60>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf880>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcf8d0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcfb00>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcfab0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcfb50>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcfc40>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcfc90>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcfbf0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcfd30>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcfdd0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcfba0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcfe70>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcfd80>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcfe20>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcff60>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcfec0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bcfce0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bcff10>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffd08d86d0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf4040>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf4090>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf40e0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4130>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4270>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4220>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf42c0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4180>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf4310>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf41d0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4360>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf43b0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf44f0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4540>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4400>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf44a0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf45e0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf4590>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4720>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4680>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4770>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf4450>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf47c0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf4810>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf4860>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf46d0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf4630>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf49a0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4900>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4a90>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf48b0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf49f0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4950>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4a40>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4ae0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4b30>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4bd0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4c20>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4cc0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4d10>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4b80>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4c70>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4d60>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4db0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4e00>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4ea0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4ef0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5030>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4fe0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4f90>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf4f40>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5080>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5120>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf50d0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5170>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf51c0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5210>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5260>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5300>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5350>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf52b0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf53a0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf53f0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5440>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf54e0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5490>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5530>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf55d0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5620>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5670>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5760>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5580>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf56c0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5710>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf57b0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5800>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5850>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf58f0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf58a0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5940>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5990>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf59e0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5a30>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5a80>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5ad0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5b20>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5b70>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5bc0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5c60>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5d50>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5cb0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5da0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5c10>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5d00>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5df0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5e40>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5e90>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf5ee0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5f30>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5f80>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf5fd0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf6020>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf6070>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf6110>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf60c0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf6160>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf61b0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf6200>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf6250>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf62a0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf62f0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf6340>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf6390>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf63e0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf6430>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf6480>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf64d0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf6520>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf6570>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf65c0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf6610>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf6660>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf66b0>],
#  [<rdkit.Chem.rdchem.Mol at 0x7fffc9bf67a0>,
#   <rdkit.Chem.rdchem.Mol at 0x7fffc9bf6700>]]

# %% [markdown]
# ## 1.2) Write poses to SDF files
# In this stage we write the poses calculated by our constrained docking into SDF files.

# %%
INITIAL_POSE_PATH = Path.cwd() / "initial_poses"
if os.path.exists(INITIAL_POSE_PATH):
    shutil.rmtree(INITIAL_POSE_PATH)
os.makedirs(INITIAL_POSE_PATH)

# %%
molecule_hashes = {}
os.chdir(INITIAL_POSE_PATH)
for query_poses in poses:
    for query_pose in query_poses:
        mol_hash = hash(query_pose)
        molecule_hashes[mol_hash] = query_pose

        filename = f"{mol_hash}.sdf"
        writer = Chem.SDWriter(filename)
        writer.write(query_pose)
        writer.close()

# %% [markdown]
# ## 1.3) Run constrained docking via the Rush platform
# In this step, we use rxdock and gnina to run our constrained docking workflow.

# %%
os.chdir(WORK_DIR)
rxdock_outputs = []

TETHERED_DOCKING_CONFIGURATION = {
    "rot_mode": "TETHERED",
    "trans_mode": "TETHERED",
    "max_rot": 3.0,
    "max_trans": 1.0,
}
for pose in molecule_hashes:
    print(pose)
    (conformers, scores, sdf) = await client.rxdock(
        None,
        None,
        {"n_runs": 10},
        TETHERED_DOCKING_CONFIGURATION,
        None,
        PROTEIN_TARGET_FILEPATH,
        INITIAL_POSE_PATH / f"{pose}.sdf",
    )
    rxdock_outputs.append((sdf, pose))

await asyncio.gather(
    *(
        sdf.download(
            filename=f"{pose}_rxdock.sdf",
        )
        for sdf, pose in rxdock_outputs
    )
)
# Out:
# 8796036112049
# 8796036112079
# 8796036112089
# 8796036112109
# 8796036111929
# 8796043268370
# 8796036112014
# 8796036112114
# 8796043267037
# 8796036111489
# 8796036111969
# 8796036112029
# 8796036111919
# 8796036111744
# 8796036111994
# 8796036112054
# 8796036112009
# 8796036111934
# 8796036111924
# 8796036111979
# 2024-05-14 01:20:03,924 - rush - INFO - Argument 7bae9de4-19a9-4326-be55-6b66923ec30b is now ModuleInstanceStatus.ADMITTED
# 2024-05-14 01:20:04,033 - rush - INFO - Argument 5e8b72ba-8a7d-4fcc-8e91-60fd3eb89b5e is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:20:04,063 - rush - INFO - Argument a074bc77-b987-4e92-aeeb-db305658ad66 is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:20:04,068 - rush - INFO - Argument e1c2df85-08b6-41ee-a122-db647f334b19 is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:20:04,082 - rush - INFO - Argument cd511845-1c88-4112-a57a-a16d05eaa326 is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:20:04,084 - rush - INFO - Argument 4155f66d-e767-494b-aea8-efedce8d099d is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:20:04,086 - rush - INFO - Argument 015663eb-158c-47b0-b3e7-32066f2e75a3 is now ModuleInstanceStatus.ADMITTED
# 2024-05-14 01:20:04,087 - rush - INFO - Argument 82f9f609-b9bb-4c33-ae9c-cd3b380e7d0a is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:20:04,145 - rush - INFO - Argument 33c4877a-0c88-42dd-9cef-18e1a6584a5a is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:20:04,166 - rush - INFO - Argument 35c4922b-9e5c-497d-a63a-1ee996608118 is now ModuleInstanceStatus.ADMITTED
# 2024-05-14 01:20:04,171 - rush - INFO - Argument e21beea3-823c-48da-a0b7-55983784f2b0 is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:20:04,488 - rush - INFO - Argument 069789d5-d81a-4a70-89af-763a6241976c is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:20:04,506 - rush - INFO - Argument 83eabcd9-8c7a-4427-b148-cdd1b12892f8 is now ModuleInstanceStatus.ADMITTED
# 2024-05-14 01:20:04,514 - rush - INFO - Argument 1be5de41-f72c-478a-810f-605b67fc14fb is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:20:04,517 - rush - INFO - Argument f090a329-1cfd-4cfe-997e-94b5dd852c58 is now ModuleInstanceStatus.ADMITTED
# 2024-05-14 01:20:04,523 - rush - INFO - Argument 4e6250a5-8da3-41db-8cd3-f5599f6da5cb is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:20:04,541 - rush - INFO - Argument d3a9f062-995a-4946-8471-3e879dee243f is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:20:04,597 - rush - INFO - Argument 05abba8d-e494-4470-b918-a99b51e0e0a9 is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:20:04,737 - rush - INFO - Argument 26143e9a-77b4-477f-a024-bf1e02f9ca45 is now ModuleInstanceStatus.ADMITTED
# 2024-05-14 01:20:04,773 - rush - INFO - Argument 1e74b6ba-522f-4f12-b9ba-df76ed5d3ad6 is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:20:07,336 - rush - INFO - Argument 7bae9de4-19a9-4326-be55-6b66923ec30b is now ModuleInstanceStatus.DISPATCHED
# 2024-05-14 01:20:08,136 - rush - INFO - Argument 015663eb-158c-47b0-b3e7-32066f2e75a3 is now ModuleInstanceStatus.DISPATCHED
# 2024-05-14 01:20:08,546 - rush - INFO - Argument f090a329-1cfd-4cfe-997e-94b5dd852c58 is now ModuleInstanceStatus.DISPATCHED
# 2024-05-14 01:20:09,997 - rush - INFO - Argument 35c4922b-9e5c-497d-a63a-1ee996608118 is now ModuleInstanceStatus.DISPATCHED
# 2024-05-14 01:20:10,283 - rush - INFO - Argument 83eabcd9-8c7a-4427-b148-cdd1b12892f8 is now ModuleInstanceStatus.DISPATCHED
# 2024-05-14 01:20:11,331 - rush - INFO - Argument 26143e9a-77b4-477f-a024-bf1e02f9ca45 is now ModuleInstanceStatus.DISPATCHED
# 2024-05-14 01:20:13,585 - rush - INFO - Argument f090a329-1cfd-4cfe-997e-94b5dd852c58 is now ModuleInstanceStatus.RUNNING
# 2024-05-14 01:20:13,901 - rush - INFO - Argument 7bae9de4-19a9-4326-be55-6b66923ec30b is now ModuleInstanceStatus.RUNNING
# 2024-05-14 01
is now ModuleInstanceStatus.RUNNING
# 2024-05-14 01:31:37,234 - rush - INFO - Argument 35c4922b-9e5c-497d-a63a-1ee996608118 is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:31:49,136 - rush - INFO - Argument 26143e9a-77b4-477f-a024-bf1e02f9ca45 is now ModuleInstanceStatus.RUNNING
# 2024-05-14 01:31:50,221 - rush - INFO - Argument d3a9f062-995a-4946-8471-3e879dee243f is now ModuleInstanceStatus.RUNNING
# 2024-05-14 01:31:50,455 - rush - INFO - Argument 83eabcd9-8c7a-4427-b148-cdd1b12892f8 is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:32:19,601 - rush - INFO - Argument e1c2df85-08b6-41ee-a122-db647f334b19 is now ModuleInstanceStatus.RUNNING
# 2024-05-14 01:32:19,605 - rush - INFO - Argument 33c4877a-0c88-42dd-9cef-18e1a6584a5a is now ModuleInstanceStatus.RUNNING
# 2024-05-14 01:32:21,433 - rush - INFO - Argument d3a9f062-995a-4946-8471-3e879dee243f is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:32:22,775 - rush - INFO - Argument 26143e9a-77b4-477f-a024-bf1e02f9ca45 is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:32:46,692 - rush - INFO - Argument 4e6250a5-8da3-41db-8cd3-f5599f6da5cb is now ModuleInstanceStatus.RUNNING
# 2024-05-14 01:32:46,765 - rush - INFO - Argument 33c4877a-0c88-42dd-9cef-18e1a6584a5a is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:33:01,670 - rush - INFO - Argument 1be5de41-f72c-478a-810f-605b67fc14fb is now ModuleInstanceStatus.RUNNING
# 2024-05-14 01:33:02,054 - rush - INFO - Argument e1c2df85-08b6-41ee-a122-db647f334b19 is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:33:30,624 - rush - INFO - Argument a074bc77-b987-4e92-aeeb-db305658ad66 is now ModuleInstanceStatus.RUNNING
# 2024-05-14 01:33:31,033 - rush - INFO - Argument 4155f66d-e767-494b-aea8-efedce8d099d is now ModuleInstanceStatus.RUNNING
# 2024-05-14 01:33:31,319 - rush - INFO - Argument 1be5de41-f72c-478a-810f-605b67fc14fb is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:33:32,444 - rush - INFO - Argument 4e6250a5-8da3-41db-8cd3-f5599f6da5cb is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:33:58,797 - rush - INFO - Argument 4e6250a5-8da3-41db-8cd3-f5599f6da5cb is now ModuleInstanceStatus.COMPLETED
# 2024-05-14 01:34:10,831 - rush - INFO - Argument 069789d5-d81a-4a70-89af-763a6241976c is now ModuleInstanceStatus.RUNNING
# 2024-05-14 01:34:11,868 - rush - INFO - Argument a074bc77-b987-4e92-aeeb-db305658ad66 is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:34:24,932 - rush - INFO - Argument 05abba8d-e494-4470-b918-a99b51e0e0a9 is now ModuleInstanceStatus.RUNNING
# 2024-05-14 01:34:25,401 - rush - INFO - Argument 4155f66d-e767-494b-aea8-efedce8d099d is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:34:37,148 - rush - INFO - Argument 05abba8d-e494-4470-b918-a99b51e0e0a9 is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:34:37,326 - rush - INFO - Argument a074bc77-b987-4e92-aeeb-db305658ad66 is now ModuleInstanceStatus.COMPLETED
# 2024-05-14 01:34:37,412 - rush - INFO - Argument 069789d5-d81a-4a70-89af-763a6241976c is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:35:04,681 - rush - INFO - Argument 069789d5-d81a-4a70-89af-763a6241976c is now ModuleInstanceStatus.COMPLETED
# [PosixPath('objects/8796036112049_rxdock.sdf'),
#  PosixPath('objects/8796036112079_rxdock.sdf'),
#  PosixPath('objects/8796036112089_rxdock.sdf'),
#  PosixPath('objects/8796036112109_rxdock.sdf'),
#  PosixPath('objects/8796036111929_rxdock.sdf'),
#  PosixPath('objects/8796043268370_rxdock.sdf'),
#  PosixPath('objects/8796036112014_rxdock.sdf'),
#  PosixPath('objects/8796036112114_rxdock.sdf'),
#  PosixPath('objects/8796043267037_rxdock.sdf'),
#  PosixPath('objects/8796036111489_rxdock.sdf'),
#  PosixPath('objects/8796036111969_rxdock.sdf'),
#  PosixPath('objects/8796036112029_rxdock.sdf'),
#  PosixPath('objects/8796036111919_rxdock.sdf'),
#  PosixPath('objects/8796036111744_rxdock.sdf'),
#  PosixPath('objects/8796036111994_rxdock.sdf'),
#  PosixPath('objects/8796036112054_rxdock.sdf'),
#  PosixPath('objects/8796036112009_rxdock.sdf'),
#  PosixPath('objects/8796036111934_rxdock.sdf'),
#  PosixPath('objects/8796036111924_rxdock.sdf'),
#  PosixPath('objects/8796036111979_rxdock.sdf')]

# %%
gnina_results = []

for pose in molecule_hashes:
    (docked_ligands, results) = await client.gnina_pdb(
        PROTEIN_TARGET_FILEPATH,
        Path.cwd() / "objects" / f"{pose}_rxdock.sdf",
        INITIAL_POSE_PATH / f"{pose}.sdf",
        {"num_modes": 10, "exhaustiveness": 8, "minimise": True},
    )
    gnina_results.append((pose, results, docked_ligands))

await asyncio.gather(*([output[1].get() for output in gnina_results]))

await asyncio.gather(
    *(
        [
            output[2].download(filename=f"{output[0]}_gnina.sdf", overwrite=True)
            for output in gnina_results
        ]
    )
)
# Out:
# 2024-05-14 01:35:58,341 - rush - INFO - Argument dde77355-43f6-457c-968b-93a165f0e6e7 is now ModuleInstanceStatus.DISPATCHED
# 2024-05-14 01
now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:37:40,422 - rush - INFO - Argument ce963333-55dc-471d-8144-bc2ecdda1243 is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:37:40,633 - rush - INFO - Argument 1d101c2a-69c4-49c8-97b0-fd1ca5572756 is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:37:40,663 - rush - INFO - Argument 5d4652e9-eb4b-4a44-8381-9e8722d2b70a is now ModuleInstanceStatus.AWAITING_UPLOAD
# 2024-05-14 01:37:47,782 - rush - INFO - Argument 825390c9-22be-477c-82c2-50115ac7b238 is now ModuleInstanceStatus.COMPLETED
# 2024-05-14 01:38:36,990 - rush - INFO - Argument ce963333-55dc-471d-8144-bc2ecdda1243 is now ModuleInstanceStatus.COMPLETED
# [PosixPath('objects/8796036112049_gnina.sdf'),
#  PosixPath('objects/8796036112079_gnina.sdf'),
#  PosixPath('objects/8796036112089_gnina.sdf'),
#  PosixPath('objects/8796036112109_gnina.sdf'),
#  PosixPath('objects/8796036111929_gnina.sdf'),
#  PosixPath('objects/8796043268370_gnina.sdf'),
#  PosixPath('objects/8796036112014_gnina.sdf'),
#  PosixPath('objects/8796036112114_gnina.sdf'),
#  PosixPath('objects/8796043267037_gnina.sdf'),
#  PosixPath('objects/8796036111489_gnina.sdf'),
#  PosixPath('objects/8796036111969_gnina.sdf'),
#  PosixPath('objects/8796036112029_gnina.sdf'),
#  PosixPath('objects/8796036111919_gnina.sdf'),
#  PosixPath('objects/8796036111744_gnina.sdf'),
#  PosixPath('objects/8796036111994_gnina.sdf'),
#  PosixPath('objects/8796036112054_gnina.sdf'),
#  PosixPath('objects/8796036112009_gnina.sdf'),
#  PosixPath('objects/8796036111934_gnina.sdf'),
#  PosixPath('objects/8796036111924_gnina.sdf'),
#  PosixPath('objects/8796036111979_gnina.sdf')]

# %% [markdown]
# ## 1.4) Sorting and presentation of results
# In this section, we sort and display the top scored molecules from our virtual screen, including the QDXF conformers for each of our poses.

# %%
POSE = 0
GNINA_SCORES = 1
GNINA_SDF_RESULTS = 2

# %%
# Destructure the gnina scores from the Rush output
gnina_results = [
    (result[POSE], result[GNINA_SCORES].value, result[GNINA_SDF_RESULTS])
    for result in gnina_results
]


def find_best_pose(sublist, sort_key=SORT_BY):
    return max(item[sort_key.value] for item in sublist[1])


sorted_hits = sorted(gnina_results, key=find_best_pose, reverse=True)

# %%
posed_conformers = []
for result in gnina_results:
    (conformers,) = await client.convert("SDF", result[GNINA_SDF_RESULTS])
    posed_conformers.append((result[POSE], conformers))
await asyncio.gather(
    *(
        [
            output[1].download(
                filename=f"{output[0]}_gnina_conformer.json", overwrite=True
            )
            for output in posed_conformers
        ]
    )
)
# Out:
# 2024-05-14 01:41:09,686 - rush - INFO - Argument bcbf0b2f-1f00-4255-bd21-579b6336a6de is now ModuleInstanceStatus.ADMITTED
# 2024-05-14 01:41:09,852 - rush - INFO - Argument 890a2a69-daff-47c7-8eb9-5d732f43bbc7 is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:41:09,964 - rush - INFO - Argument ae70b5c1-cea9-4dac-8bfb-51845d86b28f is now ModuleInstanceStatus.ADMITTED
# 2024-05-14 01:41:09,979 - rush - INFO - Argument 04c0d86d-3bea-4e12-969d-f5be615185ba is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:41:10,004 - rush - INFO - Argument 21148b46-d72e-4532-a224-6128449b87a0 is now ModuleInstanceStatus.ADMITTED
# 2024-05-14 01:41:10,007 - rush - INFO - Argument 5e2debea-df81-4633-a50e-096ec02d602b is now ModuleInstanceStatus.ADMITTED
# 2024-05-14 01:41:10,015 - rush - INFO - Argument 3f2c19a1-0408-40a9-a9c9-5405493f87ca is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:41:10,017 - rush - INFO - Argument 39ad93cf-dca2-4553-9c6d-43efeea24152 is now ModuleInstanceStatus.RESOLVING
# 2024-05-14 01:41:10
now ModuleInstanceStatus.COMPLETED
# 2024-05-14 01:42:48,654 - rush - INFO - Argument 04c0d86d-3bea-4e12-969d-f5be615185ba is now ModuleInstanceStatus.COMPLETED
# 2024-05-14 01:43:02,537 - rush - INFO - Argument 77f66c8e-f471-4fc9-b0a7-c7f555eb859a is now ModuleInstanceStatus.COMPLETED
# [PosixPath('objects/8796036112049_gnina_conformer.json'),
#  PosixPath('objects/8796036112079_gnina_conformer.json'),
#  PosixPath('objects/8796036112089_gnina_conformer.json'),
#  PosixPath('objects/8796036112109_gnina_conformer.json'),
#  PosixPath('objects/8796036111929_gnina_conformer.json'),
#  PosixPath('objects/8796043268370_gnina_conformer.json'),
#  PosixPath('objects/8796036112014_gnina_conformer.json'),
#  PosixPath('objects/8796036112114_gnina_conformer.json'),
#  PosixPath('objects/8796043267037_gnina_conformer.json'),
#  PosixPath('objects/8796036111489_gnina_conformer.json'),
#  PosixPath('objects/8796036111969_gnina_conformer.json'),
#  PosixPath('objects/8796036112029_gnina_conformer.json'),
#  PosixPath('objects/8796036111919_gnina_conformer.json'),
#  PosixPath('objects/8796036111744_gnina_conformer.json'),
#  PosixPath('objects/8796036111994_gnina_conformer.json'),
#  PosixPath('objects/8796036112054_gnina_conformer.json'),
#  PosixPath('objects/8796036112009_gnina_conformer.json'),
#  PosixPath('objects/8796036111934_gnina_conformer.json'),
#  PosixPath('objects/8796036111924_gnina_conformer.json'),
#  PosixPath('objects/8796036111979_gnina_conformer.json')]

# %%
final_output = []
for result in gnina_results:
    mhash = result[POSE]
    file_path = Path.cwd() / "objects" / f"{mhash}_gnina_conformer.json"
    conformers = json.loads(file_path.read_text())
    scores = result[GNINA_SCORES]
    final_output.append(
        (
            mhash,
            molecule_hashes[mhash],
            [{**i, **j} for i, j in zip(conformers, scores)],
        )
    )

# %% [markdown]
# ## 1.4.1) Final table presentation
# In this output, we display the outputs of our virtual screen. `rxdock` produces 10 poses per target ligand, but this protocol only displays only 2 poses by default.

# %%
N_TOP_HITS = 10
N_POSES_PER_MOLECULE = 2

for molecule in final_output[0:N_TOP_HITS]:
    print("=" * 50)
    print(f"{MolToSmiles(molecule[1])}, hash: {molecule[0]}")

    for idx, pose in enumerate(molecule[2][0:N_POSES_PER_MOLECULE]):
        print(f"POSE {idx}")
        print(f"CNN score: {pose['cnn_score']}")
        print(f"Affinity: {pose['affinity']}")
        print(f"CNN affinity: {pose['cnn_affinity']}")
        # print(f'{pose['topology']['symbols'][0:5]}') if you want to inspect the output QDXF conformer
        print("-" * 50)
# Out:
# ==================================================
# [H]c1c(OC(F)(F)F)c([H])c2sc(N([H])[H])nc2c1[H], hash: 8796036112049
# POSE 0
# CNN score: 0.78999656
# Affinity: -7.91674
# CNN affinity: 5.2846885
# --------------------------------------------------
# POSE 1
# CNN score: 0.7427761
# Affinity: -7.14572
# CNN affinity: 5.297982
# --------------------------------------------------
# ==================================================
# [H]c1c([H])c([H])c(C(=O)c2c([H])c([H])c([H])c([H])c2[H])c([H])c1[H], hash: 8796036112079
# POSE 0
# CNN score: 0.79343325
# Affinity: -8.49743
# CNN affinity: 4.441545
# --------------------------------------------------
# POSE 1
# CNN score: 0.7437881
# Affinity: -8.34523
# CNN affinity: 4.2680154
# --------------------------------------------------
# ==================================================
# [H]OC([H])([H])[C@@]([H])(O[H])C([H])([H])Oc1c([H])c([H])c([H])c([H])c1OC([H])([H])[H], hash: 8796036112089
# POSE 0
# CNN score: 0.31951967
# Affinity: -5.85809
# CNN affinity: 4.20428
# --------------------------------------------------
# POSE 1
# CNN score: 0.21155676
# Affinity: -5.71027
# CNN affinity: 4.047934
# --------------------------------------------------
# ==================================================
# [H]c1c([H])c([H])c(C([H])([H])[C@]([H])(N([H])C([H])([H])[H])C([H])([H])[H])c([H])c1[H], hash: 8796036112109
# POSE 0
# CNN score: 0.3941872
# Affinity: -6.13054
# CNN affinity: 3.9961307
# --------------------------------------------------
# POSE 1
# CNN score: 0.40530917
# Affinity: -6.1693
# CNN affinity: 4.026906
# --------------------------------------------------
# ==================================================
# [H]C([H])([H])C1(C([H])([H])[H])[C@@]2([H])C([H])([H])C(=O)[C@]1(C([H])([H])[H])C([H])([H])C2([H])[H], hash: 8796036111929
# POSE 0
# CNN score: 0.43688032
# Affinity: -4.02493
# CNN affinity: 4.2379127
# --------------------------------------------------
# POSE 1
# CNN score: 0.4367582
# Affinity: -4.02453
# CNN affinity: 4.237825
# --------------------------------------------------
# ==================================================
# [H]OC(=O)c1c(I)c(C(=O)N([H])C([H])([H])[H])c(I)c(N([H])C(=O)C([H])([H])[H])c1I, hash: 8796043268370
# POSE 0
# CNN score: 0.2393097
# Affinity: -6.25405
# CNN affinity: 5.997758
# --------------------------------------------------
# POSE 1
# CNN score: 0.18972369
# Affinity: -5.88472
# CNN affinity: 5.906266
# --------------------------------------------------
# ==================================================
# [H]c1c([H])c(N([H])[H])c([H])c([H])c1C(=O)OC([H])([H])C([H])([H])[H], hash: 8796036112014
# POSE 0
# CNN score: 0.3630398
# Affinity: -5.79463
# CNN affinity: 3.7685127
# --------------------------------------------------
# POSE 1
# CNN score: 0.35002425
# Affinity: -5.77843
# CNN affinity: 3.6861598
# --------------------------------------------------
# ==================================================
# [H]c1c([H])c([H])c([C@@]([H])(c2c([H])c([H])c(Cl)c([H])c2[H])C([H])(Cl)Cl)c(Cl)c1[H], hash: 8796036112114
# POSE 0
# CNN score: 0.20330179
# Affinity: -6.43699
# CNN affinity: 5.2734632
# --------------------------------------------------
# POSE 1
# CNN score: 0.20327556
# Affinity: -6.43714
# CNN affinity: 5.273492
# --------------------------------------------------
# ==================================================
# [H]On1c(C2([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])C2([H])[H])c([H])c(C([H])([H])[H])c([H])c1=O, hash: 8796043267037
# POSE 0
# CNN score: 0.24223359
# Affinity: -4.97447
# CNN affinity: 4.0923877
# --------------------------------------------------
# POSE 1
# CNN score: 0.24178445
# Affinity: -4.97435
# CNN affinity: 4.092431
# --------------------------------------------------
# ==================================================
# [H]c1c([H])c([H])c([C@@]2([H])C([H])([H])[C@@]2([H])N([H])[H])c([H])c1[H], hash: 8796036111489
# POSE 0
# CNN score: 0.51536447
# Affinity: -6.04337
# CNN affinity: 3.794334
# --------------------------------------------------
# POSE 1
# CNN score: 0.51512784
# Affinity: -6.03769
# CNN affinity: 3.7917943
# --------------------------------------------------
